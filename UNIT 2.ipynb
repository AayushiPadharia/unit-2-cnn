# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
num_classes = 10
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
x_train = x_train.astype('float32') / 224.0
x_test = x_test.astype('float32') / 224.0

# %%
num_classes = 10
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
vgg_model = VGG16(include_top=False, input_shape=(32, 32, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %%
model = Sequential()
model.add(vgg_model)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 14,848,586
# Trainable params: 14,848,586
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
batch_size = 100
epochs = 10

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 500/500 [==============================] - 26s 48ms/step - loss: 1.2593 - accuracy: 0.5138 - val_loss: 1.1143 - val_accuracy: 0.6030
# Epoch 2/10
# 500/500 [==============================] - 25s 51ms/step - loss: 0.9758 - accuracy: 0.6559 - val_loss: 0.9156 - val_accuracy: 0.6863
# Epoch 3/10
# 500/500 [==============================] - 24s 48ms/step - loss: 0.7886 - accuracy: 0.7313 - val_loss: 0.8373 - val_accuracy: 0.7280
# Epoch 4/10
# 500/500 [==============================] - 25s 50ms/step - loss: 0.6625 - accuracy: 0.7760 - val_loss: 0.7617 - val_accuracy: 0.7475
# Epoch 5/10
# 500/500 [==============================] - 25s 50ms/step - loss: 0.5705 - accuracy: 0.8098 - val_loss: 0.7305 - val_accuracy: 0.7686
# Epoch 6/10
# 500/500 [==============================] - 25s 50ms/step - loss: 0.4921 - accuracy: 0.8354 - val_loss: 0.7143 - val_accuracy: 0.7772
# Epoch 7/10
# 500/500 [==============================] - 24s 47ms/step - loss: 0.4209 - accuracy: 0.8597 - val_loss: 0.7029 - val_accuracy: 0.7781
# Epoch 8/10
# 500/500 [==============================] - 24s 47ms/step - loss: 0.3676 - accuracy: 0.8793 - val_loss: 0.7143 - val_accuracy: 0.7806
# Epoch 9/10
# 500/500 [==============================] - 25s 50ms/step - loss: 0.3266 - accuracy: 0.8917 - val_loss: 0.7141 - val_accuracy: 0.7938
# Epoch 10/10
# 500/500 [==============================] - 24s 47ms/step - loss: 0.2753 - accuracy: 0.9088 - val_loss: 0.7867 - val_accuracy: 0.7946
